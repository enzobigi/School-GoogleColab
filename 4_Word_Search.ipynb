# %% [markdown]
# <a href="https://colab.research.google.com/github/enzobigi/School-GoogleColab/blob/main/4_Word_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
wordslist = ["apple", "pastaa", "raspberry", "pizza", "cake", "popcorn", "cucumber", "raspberry", "banana"]

wordsearch = "RaSpbERry"
timesfound = 0

semiword = "aNA"
semiwordlower = semiword.lower()
semiwordfound = 0
semiwordletterfound = 0

for i in range (len(wordslist)):
  wordslistlower = wordslist[i].lower()
  wordsearchlower = wordsearch.lower()

  for j in range(len(wordslistlower)):

    if (wordslistlower[j]) == wordsearchlower[j]:
      if j == len(wordsearchlower) - 1:
        timesfound +=1

    elif i == 0 and semiwordlower[0] == wordslistlower[0]:
      for k in range(len(semiwordlower)):
        if semiwordlower [k] == wordslistlower [k]:
          semiwordletterfound += 1
          if semiwordletterfound == len(semiwordlower):
            print (f"Your semi-word, {semiword}, was found!")
            semiwordfound += 1

    elif wordslistlower == "pastaa":
      wordslist[i] = "pasta"

    else:
      break

      print (wordsearch[j])
if timesfound > 0:
  print (f"Your word, {wordsearch}, was found {timesfound} time(s).")
else:
  print (f"Your word, {wordsearch}, was found 0 times.")

print (wordslist)
print (f"Your semi-word, {semiword}, was found {semiwordfound} times!")
# Out:
# Your semi-word, aNA, was found!
# Your word, RaSpbERry, was found 2 time(s).
# ['apple', 'pasta', 'raspberry', 'pizza', 'cake', 'popcorn', 'cucumber', 'raspberry', 'banana']
# Your semi-word, aNA, was found 1 times!
